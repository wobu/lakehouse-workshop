# %%
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")
spark.conf.set("spark.sql.repl.eagerEval.enabled", "true")
spark.conf.set("spark.sql.catalog.demo.uri", "http://rest:8181/catalog")
spark.conf.set("spark.sql.catalog.demo.warehouse", "demo")
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://cf05283f43cf:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.6</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## DDL

# %%
# %%sql
# CREATE SCHEMA demo.nyc;
# Out:
# 25/10/28 07:43:57 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# ++
# ||
# ++
# ++

# %%
# %%sql
# CREATE TABLE demo.nyc.taxis
# (
#   vendor_id bigint,
#   trip_id bigint,
#   trip_distance float,
#   fare_amount double,
#   store_and_fwd_flag string
# )
# PARTITIONED BY (vendor_id);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## DML

# %%
# %%sql
# SELECT * FROM demo.nyc.taxis;
# Out:
# +-----------+---------+---------------+-------------+--------------------+
# | vendor_id | trip_id | trip_distance | fare_amount | store_and_fwd_flag |
# +-----------+---------+---------------+-------------+--------------------+
# +-----------+---------+---------------+-------------+--------------------+

# %%
# %%sql
# INSERT INTO demo.nyc.taxis
# VALUES
# (1, 1000371, 1.8, 15.32, 'N'),
# (2, 1000372, 2.5, 22.15, 'N'),
# (2, 1000373, 0.9, 9.01, 'N'),
# (1, 1000374, 8.4, 42.13, 'Y');
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT * FROM demo.nyc.taxis WHERE vendor_id = 2;
# Out:
# +-----------+---------+--------------------+-------------+--------------------+
# | vendor_id | trip_id |      trip_distance | fare_amount | store_and_fwd_flag |
# +-----------+---------+--------------------+-------------+--------------------+
# |         2 | 1000372 |                2.5 |       22.15 |                  N |
# |         2 | 1000373 | 0.8999999761581421 |        9.01 |                  N |
# +-----------+---------+--------------------+-------------+--------------------+

# %%
# %%sql
# EXPLAIN SELECT * FROM demo.nyc.taxis WHERE vendor_id = 2;

# %%
# %%sql
# UPDATE demo.nyc.taxis
# SET fare_amount = 99.998
# WHERE vendor_id = 2 and trip_id = 1000373

# %% [markdown]
# ## Metadata Tables

# %%
# %%sql
# SELECT * FROM demo.nyc.taxis.history;

# %%
# %%sql
# SELECT * FROM demo.nyc.taxis.snapshots;

# %%
# %%sql
# SELECT * FROM demo.nyc.taxis.files;

# %% [markdown]
# ## Data as code / branching
